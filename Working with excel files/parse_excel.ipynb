# %%
import xlrd # pip install xlrd==1.2.0

# %%
book = xlrd.open_workbook(r'C:\Users\HCL\Downloads\SOWC 2014 Stat Tables_Table 9.xlsx')
for sheet in book.sheets():
    print(sheet.name)
# Out:
# Data Notes
# Table 9

# %%
# our currently working sheet
sheet = book.sheet_by_name('Table 9 ')
print(sheet)

# %%
print(dir(sheet))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_cell_attr_to_xfx', '_cell_types', '_cell_values', '_cell_xf_indexes', '_dimncols', '_dimnrows', '_first_full_rowx', '_ixfe', '_maxdatacolx', '_maxdatarowx', '_position', '_repr_these', '_xf_index_stats', '_xf_index_to_xl_type_map', 'automatic_grid_line_colour', 'bf', 'biff_version', 'book', 'bt', 'cached_normal_view_mag_factor', 'cached_page_break_preview_mag_factor', 'cell', 'cell_note_map', 'cell_type', 'cell_value', 'cell_xf_index', 'col', 'col_label_ranges', 'col_slice', 'col_types', 'col_values', 'colinfo_map', 'columns_from_right_to_left', 'computed_column_width', 'cooked_normal_view_mag_factor', 'cooked_page_break_preview_mag_factor', '
# ...

# %%
print(sheet.nrows)
# Out:
# 303

# %%
# We need to iterate over each row, which means we
# need a for loop
for i in range(sheet.nrows):
    print(sheet.row_values(i))
# Out:
# ['', 'TABLE 9. CHILD PROTECTION', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['', '', 'TABLEAU 9. PROTECTION DE L’ENFANT', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['', '', '', 'TABLA 9. PROTECCIÓN INFANTIL', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ...

# %%
# Now that we can see each row, we need to pull out the information we want.
for i in range(sheet.nrows):
    row = sheet.row_values(i)
    for cell in row:
        print(cell)
# Out:
# TABLE 9. CHILD PROTECTION
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# TABLEAU 9. PROTECTION DE L’ENFANT
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# TABLA 9. PROTECCIÓN INFANTIL
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Countries and areas
#
#
# Child labour (%)+
# 2005–2012*
#
#
#
#
#
# Child marriage (%)
# 2005–2012*
#
#
#
# Birth registration (%)+
# 2005–2012*
#
# Female genital mutilation/cutting (%)+
# 2002–2012*
#
#
#
#
#
# Justification of wife beating (%)
#  2005–2012*
#
#
#
# Violent discipline (%)+
# 2005–2012*
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# prevalence
#
#
#
# attitudes
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# total
#
# male
#
# female
#
# married by 15
#
# married by 18
#
# total
#
# womena
#
# girlsb
#
# ...

# %% [markdown]
# ##### If you run your complete code with the nested for loop, you will notice your output is not so helpful anymore. That brings us to the second mechanism to explore our Excel file—a counter.

# %% [markdown]
# Let’s add a counter to our code so we can step through the cells and rows to find what
# we want to pull out. Be careful where you place the counter—you will have very different
# results if you place it on the cell level versus the row level.

# %%
# Outputs i and the row so we can actually see which row number has which information

count = 0
for i in range(sheet.nrows):
    if count < 10:
        row = sheet.row_values(i)
        print(i, row)
    
    count += 1
# Out:
# 0 ['', 'TABLE 9. CHILD PROTECTION', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# 1 ['', '', 'TABLEAU 9. PROTECTION DE L’ENFANT', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# 2 ['', '', '', 'TABLA 9. PROTECCIÓN INFANTIL', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# 3 ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ...

# %%
# extracting the rows where the country names are written
# those are the rows starting from 14

count = 0
for i in range(sheet.nrows):
    if count < 20:
        if i >= 14:
            row = sheet.row_values(i)
            print(i, row)
    
        count += 1
# Out:
# 14 ['', 'Afghanistan', 'Afghanistan', 'Afganistán', 10.3, '', 11.0, '', 9.6, '', 15.0, '', 40.4, '', 37.4, '', '–', '', '–', '', '–', '', '–', '', 90.2, '', 74.4, '', 74.8, '', 74.1, '', '', '', '', '', '', '', '', '', '', '', '', '']
# 15 ['', 'Albania', 'Albanie', 'Albania', 12.0, '  ', 14.4, '  ', 9.4, '  ', 0.2, '', 9.6, '', 98.6, '', '–', '', '–', '', '–', '', 36.4, '', 29.8, '', 75.1, '', 78.3, '', 71.4, '', '', '', '', '', '', '', '', '', '', '', '', '']
# 16 ['', 'Algeria', 'Algérie', 'Argelia', 4.7, 'y', 5.5, 'y', 3.9, 'y', 0.1, '', 1.8, '', 99.3, '', '–', '', '–', '', '–', '', '–', '', 67.9, '', 87.7, '', 88.8, '', 86.5, '', '', '', '', '', '', '', '', '', '', '', '', '']
# 17 ['', 'Andorra', 'Andorre', 'Andorra', '– ', ' ', '–', ' ', '–', '  ', '–', '', '–', '', 100.0, 'v', '–', '', '–', '', '–', '', '–', '', '–', '', '–', '', '–', '', '–', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ...

# %% [markdown]
# Now, we need to turn each row into our dictionary format. This will make the data
# more meaningful to us when we try to do other things with it in future chapters.

# %% [markdown]
# we
# are going to need a dictionary and we are going to use countries as keys. To pull out
# the country names, we will need to do some indexing.

# %%
count = 0
data = {}

for i in range(sheet.nrows):
    if count < 21:
        if i >= 14:
            row = sheet.row_values(i)
            country = row[1]
            data[country] = {}
        
    count += 1

print(data)
# Out:
# {'Afghanistan': {}, 'Albania': {}, 'Algeria': {}, 'Andorra': {}, 'Angola': {}, 'Antigua and Barbuda': {}, 'Argentina': {}}

# %%
data = {}
for i in range(14, sheet.nrows):
    row = sheet.row_values(i)
    country = row[1]
    data[country] = {
        'child_labor': {
            'total': [],
            'male': [],
            'female': [],
        },
        'child_marriage': {
            'married_by_15': [],
            'married_by_18': [],
        }
    }
print(data['Afghanistan'])
# Out:
# {'child_labor': {'total': [], 'male': [], 'female': []}, 'child_marriage': {'married_by_15': [], 'married_by_18': []}}

# %% [markdown]
# Let’s now populate the data. Because we have access to each column of each row using
# the index, we can populate these lists with the values from the sheet. By looking at
# our sheet and lining up which columns relate to which parts of the data, we can
# update the data dictionary to reflect the following:

# %%
data = {}
for i in range(14, sheet.nrows):
    row = sheet.row_values(i)
    country = row[1]
    data[country] = {
        'child_labor': {
            'total': [row[4], row[5]],
            'male': [row[6], row[7]],
            'female': [row[8], row[9]],
            },
        'child_marriage': {
            'married_by_15': [row[10], row[11]],
            'married_by_18': [row[12], row[13]],
            }
    }
data['Afghanistan']
# Out:
# {'child_labor': {'total': [10.3, ''], 'male': [11.0, ''], 'female': [9.6, '']},
#  'child_marriage': {'married_by_15': [15.0, ''], 'married_by_18': [40.4, '']}}
